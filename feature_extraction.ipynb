# %%
# %pip install librosa
# %pip install numpy pandas
# %pip install matplotlib
# %pip install joblib
# %pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install imblearn
# Out:
# ...
#    ---------------------------------------- 0.0/257.7 kB ? eta -:--:--
#    ---- ---------------------------------- 30.7/257.7 kB 640.0 kB/s eta 0:00:01
#    --------- ----------------------------- 61.4/257.7 kB 812.7 kB/s eta 0:00:01
#    ------------- ------------------------- 92.2/257.7 kB 744.7 kB/s eta 0:00:01
#    --------------------- ---------------- 143.4/257.7 kB 774.0 kB/s eta 0:00:01
#    ------------------------- ------------ 174.1/257.7 kB 803.1 kB/s eta 0:00:01
#    --------------------------------- ---- 225.3/257.7 kB 860.2 kB/s eta 0:00:01
#    -------------------------------------- 257.7/257.7 kB 790.5 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# feature extractoring and preprocessing data
import librosa
import matplotlib.image as mpimg
import librosa, librosa.display, os, csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import pyplot
# %matplotlib inline
import os
from PIL import Image
import pathlib
import csv

#Pytorch
import torch

from imblearn.pipeline import Pipeline

import joblib

import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

#Other
from IPython.display import Audio
from tqdm import tqdm

# %%
#Call Annotation
dataset = "C:/Users/mefta/Desktop/VSC/Model Thesis/Thesis-Meftah/RealLifeDeceptionDetection.2016/Real-life_Deception_Detection_2016/Annotation/All_Gestures_Deceptive and Truthful.csv"
train_csv = pd.read_csv(dataset, index_col=0)
train_csv
# Out:
#                      OtherGestures  Smile  Laugh  Scowl  otherEyebrowMovement  \
# id
# trial_lie_001.mp4                1      0      0      0                     1
# trial_lie_002.mp4                1      0      0      0                     0
# trial_lie_003.mp4                1      0      0      0                     0
# trial_lie_004.mp4                1      0      0      0                     1
# trial_lie_005.mp4                1      0      0      0                     0
# ...                            ...    ...    ...    ...                   ...
# trial_truth_056.mp4              1      0      0      0                     1
# trial_truth_057.mp4              1      0      0      0                     0
# trial_truth_058.mp4              1      0      0      0                     0
# trial_truth_059.mp4              0      0      0      1                     0
# trial_truth_060.mp4              0      1      0      0                     0
#
# ...

# %%
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

audio_path = 'C:/Users/mefta/Desktop/VSC/Model Thesis/Thesis-Meftah/RealLifeDeceptionDetection.2016/Real-life_Deception_Detection_2016/Audio/Mix/trial_lie_001.wav'
y, sr = librosa.load(audio_path, sr=None, duration=5)
plt.plot(y)
plt.xlabel('Time (samples)')
plt.ylabel('Amplitude')
plt.savefig('C:/Users/mefta/Desktop/VSC/Model Thesis/Thesis-Meftah/covid-19.png', bbox_inches='tight')

# %%
cmap = plt.get_cmap('inferno')
tot_rows = train_csv.shape[0]
print ('total_rows',tot_rows, 'columns: ', train_csv.shape[1])
for i in range(0,1): #Thay range(1) = range(tot_rows)
    source = train_csv.iloc[6]["Naan:32"]
    filename = 'C:/Users/mefta/Desktop/VSC/Model Thesis/Thesis-Meftah/RealLifeDeceptionDetection.2016/Real-life_Deception_Detection_2016/Audio/Mix/'+source
    y,sr = librosa.load(filename, mono=True, duration=5)
    plt.specgram(y, NFFT=2048, Fs=2, Fc=0, noverlap=128, cmap='magma', sides='default', mode='default', scale='dB');
#     plt.axis('off');
    plt.savefig(f'./{source[:-3].replace(".", "")}.png')
    print (source[:-4]) #Remove the last 4 characters ".wav"
#     plt.clf()
# Out:
# total_rows 121 columns:  40
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Python311\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Naan:32'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 5
# ...
